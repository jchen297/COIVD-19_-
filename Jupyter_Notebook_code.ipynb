# %% [markdown]
# # 疫情简单分析
# - 数据爬取 & 简单统计可视化
# - 合并海内外数据 & 可视化比较
# - 疫情分布地图可视化

# %% [markdown]
# ### 数据爬取

# %%
import json
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# 国内数据

# %%
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_other&callback=jQuery34109976904641590418_1591823412632&_=1591823412633'
china = requests.get(url).text
chinaday = json.loads(json.loads(china.replace('jQuery34109976904641590418_1591823412632(','')[:-1])['data'])['chinaDayList']
chinaTotal = chinaday[-1]
chinaday = pd.DataFrame(chinaday)
chinaday.head(2)
# Out:
#    confirm   date  dead deadRate  heal healRate  importedCase  noInfect  \
# 0       41  01.13     1      2.4     0      0.0             0         0
# 1       41  01.14     1      2.4     0      0.0             0         0
#
#    nowConfirm  nowSevere  suspect
# 0           0          0        0
# 1           0          0        0

# %% [markdown]
# 海外数据

# %%
url = 'https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoGlobalStatis'
r1 = requests.get(url).json()
gloTotal = r1['data']['FAutoGlobalStatis']

# %%
gloTotal
# Out:
# {'nowConfirm': 3470584,
#  'confirm': 7985127,
#  'heal': 4082798,
#  'dead': 431745,
#  'nowConfirmAdd': 1207,
#  'confirmAdd': 11303,
#  'healAdd': 9917,
#  'deadAdd': 179,
#  'lastUpdateTime': '2020-06-16 01:35:35'}

# %%
url = 'https://api.inews.qq.com/newsqa/v1/automation/modules/list?modules=FAutoGlobalDailyList'
gloday = requests.get(url).json()
gday = {'date':[]}
for i in gloday['data']['FAutoGlobalDailyList']:
    gday['date'].append(i['date'])
    for key in i['all']:
        if key not in gday:
            gday[key] = []
        gday[key].append(i['all'][key])
gday = pd.DataFrame(gday)
gday.head(2)
# Out:
#     date  confirm  dead  heal  newAddConfirm deadRate healRate
# 0  01.28       57     0     3              0     0.00     5.26
# 1  01.29       74     0     3             13     0.00     4.05

# %% [markdown]
# 美国数据

# %%
url = 'https://api.inews.qq.com/newsqa/v1/automation/foreign/daily/list?country=美国'
usday = requests.get(url).json()
usday = usday['data']
ustotal = usday[-1]
usday = pd.DataFrame(usday)
usday.head(2)
# Out:
#    confirm  confirm_add   date  dead  heal
# 0        5            0  01.28     0     0
# 1        5            0  01.29     0     0

# %%
# 国内
c = chinaTotal['confirm'] # 当天累计确诊
c_h = chinaTotal['heal'] # 当天累计治愈
c_d = chinaTotal['dead'] # 当天累计死亡

#美国
u = ustotal['confirm']
u_h = ustotal['heal']
u_d = ustotal['dead']

#海外
g = gloTotal['confirm']
g_h = gloTotal['heal']
g_d = gloTotal['dead']

# %% [markdown]
# ### 简单统计可视化

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

lab = ["死亡人数", "治愈人数", "确诊人数"]

b = Bar()
b.add_xaxis(lab)

b.add_yaxis("海外", [g_d,g_h,g])
b.add_yaxis("美国", [u_d,u_h,u])
b.add_yaxis("国内", [c_d,c_h,c])

b.reversal_axis()
b.set_series_opts(label_opts=opts.LabelOpts(position="right"))
b.set_global_opts(
    title_opts=opts.TitleOpts(title="最新疫情统计"),
    xaxis_opts=opts.AxisOpts(
                splitline_opts=opts.SplitLineOpts(is_show=True),
            ))
b.render("bar_reversal_axis.html")
b.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c83bdda42ccb4c32977746807b7a3a9c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c83bdda42ccb4c32977746807b7a3a9c = echarts.init(
#                     document.getElementById('c83bdda42ccb4c32977746807b7a3a9c'), 'white', {renderer: 'canvas'});
#                 var option_c83bdda42ccb4c32977746807b7a3a9c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6d77\u5916",
#             "data": [
#                 431745,
#                 4082798,
#                 7985127
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7f8e\u56fd",
#             "data": [
#                 117902,
#                 870080,
#                 2166677
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u56fd\u5185",
#             "data": [
#                 4645,
#                 79913,
#                 84778
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6d77\u5916",
#                 "\u7f8e\u56fd",
#                 "\u56fd\u5185"
#             ],
#             "selected": {
#                 "\u6d77\u5916": true,
#                 "\u7f8e\u56fd": true,
#                 "\u56fd\u5185": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6b7b\u4ea1\u4eba\u6570",
#                 "\u6cbb\u6108\u4eba\u6570",
#                 "\u786e\u8bca\u4eba\u6570"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "\u6700\u65b0\u75ab\u60c5\u7edf\u8ba1"
#         }
#     ]
# };
#                 chart_c83bdda42ccb4c32977746807b7a3a9c.setOption(option_c83bdda42ccb4c32977746807b7a3a9c);
#         });
#     </script>

# %% [markdown]
# 从上图可以看出：
#
# - 中国对疫情有很好的控制。
#
# - 而美国的确诊人数接近海外总数的三分之一

# %%
# 极坐标图统计，于上图重复
# from pyecharts import options as opts
# from pyecharts.charts import Polar

# p =Polar()
# p.add_schema(
#         radiusaxis_opts=opts.RadiusAxisOpts(data=['死亡','治愈','累计确诊'], type_="category"),
#         angleaxis_opts=opts.AngleAxisOpts(is_clockwise=True, max_=g),
#     )

# p.add("国内", [c_d,c_h,c], type_="bar")
# p.add("美国", [u_d,u_h,u], type_="bar")
# p.add("海外", [g_d,g_h,g], type_="bar")
# p.set_global_opts(title_opts=opts.TitleOpts(title="疫情"))
# p.set_series_opts(label_opts=opts.LabelOpts(is_show=True))
# p.render("疫情.html")
# p.render_notebook()

# %% [markdown]
# ### 合并海内外数据(按照日期合并)

# %%
# y = us, x = 海外
# ['confirm_x','confirm_y','confirm']
merged = gday.merge(usday, on="date").merge(chinaday, on="date")
merged[['confirm_x','confirm_y','confirm']].head()
# Out:
#    confirm_x  confirm_y  confirm
# 0         57          5     5997
# 1         74          5     7736
# 2         98          6     9720
# 3        124          6    11821
# 4        139          7    14411

# %% [markdown]
# 调整日期格式

# %%
from pyecharts.faker import Faker
Faker.months
# Out:
# ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']

# %%
def dateformate(x):
    mon = int(x[0:2])
    day = int(x[3:])
    return Faker.months[mon-1] + ' ' + str(day) + '日'
merged['date_f'] = merged.apply(lambda row: dateformate(row['date']), axis=1)

# %%
merged['date_f'][0:5]
# Out:
# 0    1月 28日
# 1    1月 29日
# 2    1月 30日
# 3    1月 31日
# 4     2月 1日
# Name: date_f, dtype: object

# %%
# def valuation_formula(x, y):
#     if x < y:
#         return y
#     else:
#         return x
# merged['confirm_x'] = merged.apply(lambda row: valuation_formula(row['confirm_x'], row['confirm_y']), axis=1)
# merged['dead_x'] = merged.apply(lambda row: valuation_formula(row['dead_x'], row['dead_y']), axis=1)
# merged['heal_x'] = merged.apply(lambda row: valuation_formula(row['heal_x'], row['heal_y']), axis=1)

# %%
merged.head()
# Out:
#     date  confirm_x  dead_x  heal_x  newAddConfirm deadRate_x healRate_x  \
# 0  01.28         57       0       3              0       0.00       5.26
# 1  01.29         74       0       3             13       0.00       4.05
# 2  01.30         98       0       6             22       0.00       6.12
# 3  01.31        124       0      11             20       0.00       8.87
# 4  02.01        139       0      11             13       0.00       7.91
#
#    confirm_y  confirm_add  dead_y  ...  dead  deadRate_y  heal healRate_y  \
# 0          5            0       0  ...   132         2.2   103        1.7
# 1          5            0       0  ...   170         2.2   124        1.6
# 2          6            1       0  ...   213         2.2   171        1.8
# 3          6            0       0  ...   259         2.2   243        2.1
# 4          7            1       0  ...   304         2.1   328        2.3
#
#    importedCase noInfect  nowConfirm  nowSevere  suspect  date_f
# 0             0        0        5762       1239     9239  1月 28日
# 1             0        0        7442       1370    12167  1月 29日
# 2             0        0        9336       1527    15238  1月 30日
# 3             0        0       11319       1795    17988  1月 31日
# 4             0        0       13779       2110    19544   2月 1日
#
# [5 rows x 22 columns]

# %%
# merged.loc[:,'date']
# len(merged['date_f'])
temp = merged['confirm_x'].copy()
t = merged.copy()

# %%
# arr={'confirm_x':[0]}
# s = pd.DataFrame(arr)
# len(temp)
# temp.index = [i for i in range(1,136)]
# temp[0] = 0
# temp = temp.drop(len(temp)-1)
# t['confirm_xX'] = temp

# %%
# t[['confirm_x','confirm_xX']]

# %%
def growth_rate(df,column):
    arr={column:[0]}
    s = pd.DataFrame(arr)
    temp = df[column].copy()
    temp.index = [i for i in range(1,len(temp)+1)]
    temp[0] = 0
    temp = temp.drop(len(temp)-1)
    m = df[column].copy()
    return round((m-temp)/temp*100,1)

# %%
#growth_rate(merged,'confirm_x')
len(merged)
# Out:
# 139

# %% [markdown]
# ### 数据可视化比较

# %%
def grow_plot(start,end,merged,col,function,lab,boolean,position):
    import pyecharts.options as opts
    from pyecharts.charts import Line

    day_list = list(merged.loc[start:end,'date_f'])

    num_g = function(merged.loc[start:end],col + '_x')
    num_c = function(merged.loc[start:end],col)
    num_u = function(merged.loc[start:end],col + '_y')

    if boolean == True:
        ma = [opts.MarkPointItem(type_="max")]
    else:
        ma = None
    # width="1600px", height="800px")
    l=Line(init_opts=opts.InitOpts())
    l.add_xaxis(xaxis_data=day_list)
    l.add_yaxis(
            series_name="海外",
            y_axis=num_g,
            markpoint_opts=opts.MarkPointOpts(data=ma),
            is_smooth=True,
            label_opts=opts.LabelOpts(is_show=False),
            linestyle_opts=opts.LineStyleOpts(width=2)
        )
    l.add_yaxis(
            series_name="国内",
            y_axis=num_c,
            markpoint_opts=opts.MarkPointOpts(data=ma),
            label_opts=opts.LabelOpts(is_show=False),
            linestyle_opts=opts.LineStyleOpts(width=2)
        )

    l.add_yaxis(
            series_name="美国",
            y_axis=num_u,
            markpoint_opts=opts.MarkPointOpts(data=ma),
            is_smooth=True,
            label_opts=opts.LabelOpts(is_show=False),
            linestyle_opts=opts.LineStyleOpts(width=2)
        )
    title = ''
    if 'confirm' in col:
        title = '疫情累计确诊'
    elif 'heal' in col:
        title = '疫情治愈'
    elif 'dead' in col:
        title = '疫情死亡'
        
    if position == 'r':
        title_opts=opts.TitleOpts(title=title, subtitle=f"{day_list[0]} 至 {day_list[-1]}", pos_right="5%")
    else:
        title_opts=opts.TitleOpts(title=title, subtitle=f"{day_list[0]} 至 {day_list[-1]}")
    l.set_global_opts(
            title_opts,
            #tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),
            #xaxis_opts=opts.AxisOpts(boundary_gap=False),
            yaxis_opts=opts.AxisOpts(
                axislabel_opts=opts.LabelOpts(formatter='{value}'+f"{lab}"),
                splitline_opts=opts.SplitLineOpts(is_show=True),
            )

        )
    # l.set_series_opts(
    #         markarea_opts=opts.MarkAreaOpts(
    #             data=[
    #                 opts.MarkAreaItem(name="早高峰", x=("07:30", "10:00")),
    #                 opts.MarkAreaItem(name="晚高峰", x=("17:30", "21:15")),
    #             ]
    #         )
    #     )
    return l

# %%
def normal(df,column):
    return df[column]

# %%
from pyecharts.charts import Grid

l = grow_plot(71,135,merged,'confirm',normal,'人',False,'r')
l2 = grow_plot(0,70,merged,'confirm',normal,'人',False,'l')
grid = Grid()
grid.add(l, grid_opts=opts.GridOpts(pos_left="55%"))
grid.add(l2, grid_opts=opts.GridOpts(pos_right="55%"))

grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="99b20d65088c4ca682de12db72980efc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_99b20d65088c4ca682de12db72980efc = echarts.init(
#                     document.getElementById('99b20d65088c4ca682de12db72980efc'), 'white', {renderer: 'canvas'});
#                 var option_99b20d65088c4ca682de12db72980efc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6d77\u5916",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "4\u6708 8\u65e5",
#                     1366952
#                 ],
#                 [
#                     "4\u6708 9\u65e5",
#                     1450303
#                 ],
#                 [
#                     "4\u6708 10\u65e5",
#                     1538640
#                 ],
#                 [
#                     "4\u6708 11\u65e5",
#                     1637683
#                 ],
#                 [
#                     "4\u6708 12\u65e5",
#                     1716963
#                 ],
#                 [
#                     "4\u6708 13\u65e5",
#                     1788161
#                 ],
#                 [
#                     "4\u6708 14\u65e5",
#                     1858355
#                 ],
#                 [
#                     "4\u6708 15\u65e5",
#                     1934291
#                 ],
#                 [
#                     "4\u6708 16\u65e5",
#                     2017483
#                 ],
#                 [
#                     "4\u6708 17\u65e5",
#                     2098707
#                 ],
#                 [
#                     "4\u6708 18\u65e5",
#                     2190113
#                 ],
#                 [
#                     "4\u6708 19\u65e5",
#                     2271717
#                 ],
#                 [
#                     "4\u6708 20\u65e5",
#                     2339647
#                 ],
#                 [
#                     "4\u6708 21\u65e5",
#                     2416345
#                 ],
#                 [
#                     "4\u6708 22\u65e5",
#                     2509897
#                 ],
#                 [
#                     "4\u6708 23\u65e5",
#                     2574719
#                 ],
#                 [
#                     "4\u6708 24\u65e5",
#                     2659664
#                 ],
#                 [
#                     "4\u6708 25\u65e5",
#                     2756365
#                 ],
#                 [
#                     "4\u6708 26\u65e5",
#                     2835787
#                 ],
#                 [
#                     "4\u6708 27\u65e5",
#                     2908094
#                 ],
#                 [
#                     "4\u6708 28\u65e5",
#                     2980553
#                 ],
#                 [
#                     "4\u6708 29\u65e5",
#                     3059873
#                 ],
#                 [
#                     "4\u6708 30\u65e5",
#                     3141226
#                 ],
#                 [
#                     "5\u6708 1\u65e5",
#                     3240690
#                 ],
#                 [
#                     "5\u6708 2\u65e5",
#                     3339282
#                 ],
#                 [
#                     "5\u6708 3\u65e5",
#                     3395941
#                 ],
#                 [
#                     "5\u6708 4\u65e5",
#                     3506189
#                 ],
#                 [
#                     "5\u6708 5\u65e5",
#                     3588157
#                 ],
#                 [
#                     "5\u6708 6\u65e5",
#                     3668152
#                 ],
#                 [
#                     "5\u6708 7\u65e5",
#                     3763009
#                 ],
#                 [
#                     "5\u6708 8\u65e5",
#                     3860594
#                 ],
#                 [
#                     "5\u6708 9\u65e5",
#                     3958892
#                 ],
#                 [
#                     "5\u6708 10\u65e5",
#                     4044639
#                 ],
#                 [
#                     "5\u6708 11\u65e5",
#                     4127234
#                 ],
#                 [
#                     "5\u6708 12\u65e5",
#                     4205093
#                 ],
#                 [
#                     "5\u6708 13\u65e5",
#                     4289731
#                 ],
#                 [
#                     "5\u6708 14\u65e5",
#                     4379103
#                 ],
#                 [
#                     "5\u6708 15\u65e5",
#                     4477725
#                 ],
#                 [
#                     "5\u6708 16\u65e5",
#                     4573159
#                 ],
#                 [
#                     "5\u6708 17\u65e5",
#                     4663087
#                 ],
#                 [
#                     "5\u6708 18\u65e5",
#                     4746857
#                 ],
#                 [
#                     "5\u6708 19\u65e5",
#                     4836178
#                 ],
#                 [
#                     "5\u6708 20\u65e5",
#                     4929628
#                 ],
#                 [
#                     "5\u6708 21\u65e5",
#                     5032360
#                 ],
#                 [
#                     "5\u6708 22\u65e5",
#                     5132438
#                 ],
#                 [
#                     "5\u6708 23\u65e5",
#                     5253256
#                 ],
#                 [
#                     "5\u6708 24\u65e5",
#                     5345699
#                 ],
#                 [
#                     "5\u6708 25\u65e5",
#                     5448370
#                 ],
#                 [
#                     "5\u6708 26\u65e5",
#                     5531463
#                 ],
#                 [
#                     "5\u6708 27\u65e5",
#                     5627372
#                 ],
#                 [
#                     "5\u6708 28\u65e5",
#                     5733681
#                 ],
#                 [
#                     "5\u6708 29\u65e5",
#                     5854300
#                 ],
#                 [
#                     "5\u6708 30\u65e5",
#                     5972350
#                 ],
#                 [
#                     "5\u6708 31\u65e5",
#                     6108396
#                 ],
#                 [
#                     "6\u6708 1\u65e5",
#                     6210041
#                 ],
#                 [
#                     "6\u6708 2\u65e5",
#                     6315311
#                 ],
#                 [
#                     "6\u6708 3\u65e5",
#                     6386214
#                 ],
#                 [
#                     "6\u6708 4\u65e5",
#                     6556454
#                 ],
#                 [
#                     "6\u6708 5\u65e5",
#                     6689166
#                 ],
#                 [
#                     "6\u6708 6\u65e5",
#                     6833081
#                 ],
#                 [
#                     "6\u6708 7\u65e5",
#                     6966334
#                 ],

# %% [markdown]
# - 整个海外的情况一直没有得到很好的控制所以一直在上升，而且从二月底开始上升的幅度越来越大
#
# -  而中国控制的特别好，在二月底开始就趋于稳定

# %%
def hd_rate(df,column):
    if '_' in column:
        hd_rate = df[column] / df['confirm'+column[-2:]] 
    else:
        hd_rate = df[column] / df['confirm'] 
    return round(hd_rate*100,1)

# %%
l = grow_plot(0,135,merged,'heal',hd_rate,'%',True,'r')
l2 = grow_plot(0,135,merged,'dead',hd_rate,'%',True,'l')
grid = Grid()
grid.add(l, grid_opts=opts.GridOpts(pos_bottom="60%"))
grid.add(l2, grid_opts=opts.GridOpts(pos_top="60%"))
grid.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5df9cd39db0949cc90eb9c71c8581149" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5df9cd39db0949cc90eb9c71c8581149 = echarts.init(
#                     document.getElementById('5df9cd39db0949cc90eb9c71c8581149'), 'white', {renderer: 'canvas'});
#                 var option_5df9cd39db0949cc90eb9c71c8581149 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6d77\u5916",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": true,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708 28\u65e5",
#                     5.3
#                 ],
#                 [
#                     "1\u6708 29\u65e5",
#                     4.1
#                 ],
#                 [
#                     "1\u6708 30\u65e5",
#                     6.1
#                 ],
#                 [
#                     "1\u6708 31\u65e5",
#                     8.9
#                 ],
#                 [
#                     "2\u6708 1\u65e5",
#                     7.9
#                 ],
#                 [
#                     "2\u6708 2\u65e5",
#                     7.4
#                 ],
#                 [
#                     "2\u6708 3\u65e5",
#                     7.8
#                 ],
#                 [
#                     "2\u6708 4\u65e5",
#                     10.7
#                 ],
#                 [
#                     "2\u6708 5\u65e5",
#                     10.4
#                 ],
#                 [
#                     "2\u6708 6\u65e5",
#                     11.1
#                 ],
#                 [
#                     "2\u6708 7\u65e5",
#                     9.9
#                 ],
#                 [
#                     "2\u6708 8\u65e5",
#                     9.7
#                 ],
#                 [
#                     "2\u6708 9\u65e5",
#                     9.6
#                 ],
#                 [
#                     "2\u6708 10\u65e5",
#                     9.4
#                 ],
#                 [
#                     "2\u6708 11\u65e5",
#                     11.1
#                 ],
#                 [
#                     "2\u6708 12\u65e5",
#                     11.3
#                 ],
#                 [
#                     "2\u6708 13\u65e5",
#                     11.1
#                 ],
#                 [
#                     "2\u6708 14\u65e5",
#                     11.4
#                 ],
#                 [
#                     "2\u6708 15\u65e5",
#                     10.1
#                 ],
#                 [
#                     "2\u6708 16\u65e5",
#                     12.2
#                 ],
#                 [
#                     "2\u6708 17\u65e5",
#                     11.0
#                 ],
#                 [
#                     "2\u6708 18\u65e5",
#                     12.6
#                 ],
#                 [
#                     "2\u6708 19\u65e5",
#                     12.5
#                 ],
#                 [
#                     "2\u6708 20\u65e5",
#                     11.6
#                 ],
#                 [
#                     "2\u6708 21\u65e5",
#                     11.5
#                 ],
#                 [
#                     "2\u6708 22\u65e5",
#                     10.1
#                 ],
#                 [
#                     "2\u6708 23\u65e5",
#                     8.2
#                 ],
#                 [
#                     "2\u6708 24\u65e5",
#                     7.6
#                 ],
#                 [
#                     "2\u6708 25\u65e5",
#                     7.5
#                 ],
#                 [
#                     "2\u6708 26\u65e5",
#                     7.1
#                 ],
#                 [
#                     "2\u6708 27\u65e5",
#                     7.9
#                 ],
#                 [
#                     "2\u6708 28\u65e5",
#                     7.3
#                 ],
#                 [
#                     "2\u6708 29\u65e5",
#                     7.2
#                 ],
#                 [
#                     "3\u6708 1\u65e5",
#                     13.9
#                 ],
#                 [
#                     "3\u6708 2\u65e5",
#                     5.8
#                 ],
#                 [
#                     "3\u6708 3\u65e5",
#                     7.4
#                 ],
#                 [
#                     "3\u6708 4\u65e5",
#                     6.5
#                 ],
#                 [
#                     "3\u6708 5\u65e5",
#                     6.7
#                 ],
#                 [
#                     "3\u6708 6\u65e5",
#                     8.0
#                 ],
#                 [
#                     "3\u6708 7\u65e5",
#                     7.5
#                 ],
#                 [
#                     "3\u6708 8\u65e5",
#                     11.9
#                 ],
#                 [
#                     "3\u6708 9\u65e5",
#                     11.7
#                 ],
#                 [
#                     "3\u6708 10\u65e5",
#                     11.8
#                 ],
#                 [
#                     "3\u6708 11\u65e5",
#                     12.8
#                 ],
#                 [
#                     "3\u6708 12\u65e5",
#                     11.9
#                 ],
#                 [
#                     "3\u6708 13\u65e5",
#                     11.2
#                 ],
#                 [
#                     "3\u6708 14\u65e5",
#                     11.8
#                 ],
#                 [
#                     "3\u6708 15\u65e5",
#                     11.7
#                 ],
#                 [
#                     "3\u6708 16\u65e5",
#                     11.3
#                 ],
#                 [
#                     "3\u6708 17\u65e5",
#                     11.0
#                 ],
#                 [
#                     "3\u6708 18\u65e5",
#                     11.0
#                 ],
#                 [
#                     "3\u6708 19\u65e5",
#                     10.5
#                 ],
#                 [
#                     "3\u6708 20\u65e5",
#                     10.4
#                 ],
#                 [
#                     "3\u6708 21\u65e5",
#                     10.4
#                 ],
#                 [
#                     "3\u6708 22\u65e5",
#                     10.1
#                 ],
#                 [
#                     "3\u6708 23\u65e5",
#                     9.9
#                 ],
#                 [
#                     "3\u6708 24\u65e5",
#                     9.3
#                 ],
#                 [
#                     "3\u6708 25\u65e5",
#                     9.9
#                 ],
#                 [
#                     "3\u6708 26\u65e5",
#                     10.1
#                 ],
#                 [
#                     "3\u6708 27\u65e5",
#                     10.8
#                 ],
#                 [
#                     "3\u6708 28\u65e5",
#                     11.0
#                 ],
#                 [
#                     "3\u6708 29\u65e5",
#                     11.3
#                 ],
#                 [
#                     "3\u6708 30\u65e5",
#                     11.9
#                 ],

# %% [markdown]
# - 中国的治愈率一直在稳步上升，现在稳定在94%左右
#
# - 海外的死亡率已经跟国内相近，但是治愈率现在才50%。如果以国内的情况来作为标准的话，海外的治愈率需要达到90%以上疫情就能算是得到控制了。

# %%
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5&callback=jQuery34103376894568990161_1592185687344&_=1592185687345'
china_map = requests.get(url).text
china_map = json.loads(json.loads(china_map.replace('jQuery34103376894568990161_1592185687344(','')[:-1])['data'])
china_map = china_map['areaTree'][0]['children']

# %%
provinces = []
value = []
for i in china_map:
    provinces.append(i['name'])
    value.append(i['total']['confirm'])

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

data = [list(z) for z in zip(provinces, value)]

w = Map()
w.add("", data, "china", is_map_symbol_show=False)
w.set_global_opts(
        title_opts=opts.TitleOpts(title="最新国内疫情分布"),
        visualmap_opts=opts.VisualMapOpts(max_=max(value)),
    )
w.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ce863c5a044e4da48bbcbd261e93cfde" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ce863c5a044e4da48bbcbd261e93cfde = echarts.init(
#                     document.getElementById('ce863c5a044e4da48bbcbd261e93cfde'), 'white', {renderer: 'canvas'});
#                 var option_ce863c5a044e4da48bbcbd261e93cfde = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 673
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1112
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1625
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 588
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 692
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 237
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 362
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 445
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 313
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 196
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 331
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 582
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 792
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 171
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 151
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1276
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 68135
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 932
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 198
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 947
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 653
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 254
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1019
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1268
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 991
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 185
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 139
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6700\u65b0\u56fd\u5185\u75ab\u60c5\u5206\u5e03"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 68135,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_ce863c5a044e4da48bbcbd261e93cfde.setOption(option_ce863c5a044e4da48bbcbd261e93cfde);
#         });
#     </script>

# %% [markdown]
# 因为湖北武汉是疫情开始的地方，那里的感染人数远远高于其他地区

# %%
for i in range(len(data)):
    if data[i][0] == '湖北':
        del data[i]
        break

# %%
def del_max(value):
    x = value
    for i in range(len(x)):
        if x[i] > 10000:
            del x[i]
            break
    return x
vv = del_max(value)

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

w = Map()
w.add("", data, "china", is_map_symbol_show=False)
w.set_global_opts(
        title_opts=opts.TitleOpts(title="最新国内疫情分布"),
        visualmap_opts=opts.VisualMapOpts(max_=max(vv)),
    )
w.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="7431632070214eb99fb18cdad405efd4" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_7431632070214eb99fb18cdad405efd4 = echarts.init(
#                     document.getElementById('7431632070214eb99fb18cdad405efd4'), 'white', {renderer: 'canvas'});
#                 var option_7431632070214eb99fb18cdad405efd4 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 673
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 1112
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1625
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 588
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 692
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 237
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 362
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 445
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 313
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 196
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 331
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 582
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 792
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 171
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 151
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1276
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 155
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 932
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 198
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 147
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 947
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 653
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 254
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1019
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1268
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 991
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 185
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 139
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6700\u65b0\u56fd\u5185\u75ab\u60c5\u5206\u5e03"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 1625,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_7431632070214eb99fb18cdad405efd4.setOption(option_7431632070214eb99fb18cdad405efd4);
#         });
#     </script>

# %% [markdown]
# 不看湖北，疫情主要分布在有大城市的省份和黑龙江省

# %%
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_foreign&callback=jQuery34103376894568990161_1592185687348&_=1592185687349'
globa = requests.get(url).text
globa = json.loads(json.loads(globa.replace('jQuery34103376894568990161_1592185687348(','')[:-1])['data'])
globa = globa['foreignList']

# %%
# with open('国家对应表.json','w',encoding='utf-8') as file:
#     file.write(json.dumps(nameMap,indent=2,ensure_ascii=False))

# %%
temp = []
temp_v = []
orginal = {}
for i in globa:
    temp.append(i['name'])
    temp_v.append(i['confirm'])
    orginal[i['name']] = i['confirm']

# %%
with open("国家对应表.json",'r',encoding='utf-8') as load_f:
    load_dict = json.load(load_f)

con = []
check = {}
for key in load_dict:
    con.append(load_dict[key])
    check[load_dict[key]] = key

countries = []
values = []
for i in range(len(temp)):
    if temp[i] in con:
        countries.append(check[temp[i]])
        values.append(temp_v[i])

# %%
# 对应表多余的国家
# for i in con:
#     if i not in temp:
#         print(i)

# %%
# 配对不到的国家
# for i in temp:
#     if i not in con:
#         print(i)

# %%
# 手动添加报错的国家
countries.append(check['孟加拉国'])
values.append(orginal['孟加拉'])

countries.append(check['刚果民主共和国'])
values.append(orginal['刚果（金）'])

countries.append(check['刚果'])
values.append(orginal['刚果（布）'])

countries.append(check['中非'])
values.append(orginal['中非共和国'])

countries.append(check['波斯尼亚和黑塞哥维那'])
values.append(orginal['波黑'])

countries.append(check['马其顿'])
values.append(orginal['北马其顿'])

countries.append('China')
values.append(chinaTotal['confirm'])

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

data = [list(z) for z in zip(countries, values)]

w = Map()
w.add("", data, "world",is_map_symbol_show=False)
w.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
range_color = ['#313695', '#ffffbf', '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
# ["lightskyblue",'blue', "yellow", "orangered"]
w.set_global_opts(
        title_opts=opts.TitleOpts(title="疫情分布"),
        visualmap_opts=opts.VisualMapOpts(max_=data[0][1],range_text=["High", "Low"],
            is_calculable=True,
            range_color=range_color),
    )
w.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="078a2905b2bd4ef48464731671621a84" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_078a2905b2bd4ef48464731671621a84 = echarts.init(
#                     document.getElementById('078a2905b2bd4ef48464731671621a84'), 'white', {renderer: 'canvas'});
#                 var option_078a2905b2bd4ef48464731671621a84 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "United States",
#                     "value": 2166677
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 291008
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 104145
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 97689
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 63929
#                 },
#                 {
#                     "name": "Iran",
#                     "value": 44606
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 44526
#                 },
#                 {
#                     "name": "France",
#                     "value": 40751
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 15526
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 14476
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 11899
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 11814
#                 },
#                 {
#                     "name": "Korea",
#                     "value": 9976
#                 },
#                 {
#                     "name": "Turkey",
#                     "value": 9217
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 8724
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 6408
#                 },
#                 {
#                     "name": "Israel",
#                     "value": 4347
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 4284
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 4256
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 4245
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 3700
#                 },
#                 {
#                     "name": "Czech Rep.",
#                     "value": 2817
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 2724
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 2626
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 2615
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 2449
#                 },
#                 {
#                     "name": "Luxembourg",
#                     "value": 1988
#                 },
#                 {
#                     "name": "Romania",
#                     "value": 1952
#                 },
#                 {
#                     "name": "Ecuador",
#                     "value": 1924
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 1905
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 1836
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 1724
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 1625
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1546
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 1524
#                 },
#                 {
#                     "name": "Saudi Arabia",
#                     "value": 1453
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 1414
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 1280
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 1240
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 1156
#                 },
#                 {
#                     "name": "India",
#                     "value": 1071
#                 },
#                 {
#                     "name": "Iceland",
#                     "value": 1020
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 993
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 989
#                 },
#                 {
#                     "name": "Dominican Rep.",
#                     "value": 901
#                 },
#                 {
#                     "name": "Singapore Rep.",
#                     "value": 879
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 852
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 820
#                 },
#                 {
#                     "name": "Croatia",
#                     "value": 713
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 702
#                 },
#                 {
#                     "name": "Slovenia",
#                     "value": 684
#                 },
#                 {
#                     "name": "Estonia",
#                     "value": 645
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 634
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 611
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 609
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 589
#                 },
#                 {
#                     "name": "Azerbaijan",
#                     "value": 584
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 547

# %% [markdown]
# 美国疫情最为严重

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

data = [list(z) for z in zip(countries, values)]
world_v = del_max(values)
for i in range(len(data)):
    if data[i][0] == 'United States':
        del data[i]
        break

w = Map()
w.add("", data, "world",is_map_symbol_show=False)
w.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
range_color = ['#313695', '#ffffbf', '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
# ["lightskyblue",'blue', "yellow", "orangered"]
w.set_global_opts(
        title_opts=opts.TitleOpts(title="疫情分布"),
        visualmap_opts=opts.VisualMapOpts(max_=data[0][1],range_text=["High", "Low"],
            is_calculable=True,
            range_color=range_color),
    )
w.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="43688fb42112434395d7fbba1723d108" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_43688fb42112434395d7fbba1723d108 = echarts.init(
#                     document.getElementById('43688fb42112434395d7fbba1723d108'), 'white', {renderer: 'canvas'});
#                 var option_43688fb42112434395d7fbba1723d108 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "Spain",
#                     "value": 291008
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 104145
#                 },
#                 {
#                     "name": "Italy",
#                     "value": 97689
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 63929
#                 },
#                 {
#                     "name": "Iran",
#                     "value": 44606
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 44526
#                 },
#                 {
#                     "name": "France",
#                     "value": 40751
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 15526
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 14476
#                 },
#                 {
#                     "name": "Belgium",
#                     "value": 11899
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 11814
#                 },
#                 {
#                     "name": "Korea",
#                     "value": 9976
#                 },
#                 {
#                     "name": "Turkey",
#                     "value": 9217
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 8724
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 6408
#                 },
#                 {
#                     "name": "Israel",
#                     "value": 4347
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 4284
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 4256
#                 },
#                 {
#                     "name": "Australia",
#                     "value": 4245
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 3700
#                 },
#                 {
#                     "name": "Czech Rep.",
#                     "value": 2817
#                 },
#                 {
#                     "name": "Denmark",
#                     "value": 2724
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 2626
#                 },
#                 {
#                     "name": "Ireland",
#                     "value": 2615
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 2449
#                 },
#                 {
#                     "name": "Luxembourg",
#                     "value": 1988
#                 },
#                 {
#                     "name": "Romania",
#                     "value": 1952
#                 },
#                 {
#                     "name": "Ecuador",
#                     "value": 1924
#                 },
#                 {
#                     "name": "Poland",
#                     "value": 1905
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 1836
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 1724
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 1625
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 1546
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 1524
#                 },
#                 {
#                     "name": "Saudi Arabia",
#                     "value": 1453
#                 },
#                 {
#                     "name": "Indonesia",
#                     "value": 1414
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 1280
#                 },
#                 {
#                     "name": "Finland",
#                     "value": 1240
#                 },
#                 {
#                     "name": "Greece",
#                     "value": 1156
#                 },
#                 {
#                     "name": "India",
#                     "value": 1071
#                 },
#                 {
#                     "name": "Iceland",
#                     "value": 1020
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 993
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 989
#                 },
#                 {
#                     "name": "Dominican Rep.",
#                     "value": 901
#                 },
#                 {
#                     "name": "Singapore Rep.",
#                     "value": 879
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 852
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 820
#                 },
#                 {
#                     "name": "Croatia",
#                     "value": 713
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 702
#                 },
#                 {
#                     "name": "Slovenia",
#                     "value": 684
#                 },
#                 {
#                     "name": "Estonia",
#                     "value": 645
#                 },
#                 {
#                     "name": "Qatar",
#                     "value": 634
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 611
#                 },
#                 {
#                     "name": "Egypt",
#                     "value": 609
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 589
#                 },
#                 {
#                     "name": "Azerbaijan",
#                     "value": 584
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 547
#                 },
#                 {
#                     "name": "Morocco",
#                     "value": 516

# %% [markdown]
# 出去美国，西班牙最严重，然后是意大利，英国。然后就是中国，德国，法国，伊朗，加拿大...
